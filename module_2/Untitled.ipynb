# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from itertools import combinations
from scipy.stats import ttest_ind

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
cacao = pd.read_csv('cacao_flavors.xls')

# %%
display(cacao.head(10))
cacao.info()
# Out:
#    Bar id Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0       1                   A. Morin                       Agua Grande  1876
# 1       2                   A. Morin                             Kpime  1676
# 2       3                   A. Morin                            Atsane  1676
# 3       4                   A. Morin                             Akata  1680
# 4       5                   A. Morin                            Quilla  1704
# 5       6                   A. Morin                          Carenero  1315
# 6       7                   A. Morin                              Cuba  1315
# 7       8                   A. Morin                      Sur del Lago  1315
# 8       9                                               Puerto Cabello  1319
# 9      10                   A. Morin                           Pablino  1319
#
#    Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# ...

# %%
cacao.columns = ['bar_id',
                 'company',
                 'specific_origin',
                 'ref',
                 'review_date',
                 'cocoa_percent',
                 'company_location',
                 'rating',
                 'bean_type',
                 'broad_origin'
                ]

# %%
cacao
# Out:
#       bar_id   company     specific_origin   ref  review_date cocoa_percent  \
# 0          1  A. Morin         Agua Grande  1876         2016           63%
# 1          2  A. Morin               Kpime  1676         2015           70%
# 2          3  A. Morin              Atsane  1676         2015          670%
# 3          4  A. Morin               Akata  1680         2015           70%
# 4          5  A. Morin              Quilla  1704         2015           70%
# ...      ...       ...                 ...   ...          ...           ...
# 1790    1791    Zotter                Peru   647         2011           70%
# 1791    1792    Zotter               Congo   749         2011           65%
# 1792    1793    Zotter        Kerala State   749         2011           65%
# 1793    1794    Zotter        Kerala State   781         2011           62%
# 1794    1795    Zotter  Brazil, Mitzi Blue   486         2010           65%
#
#      company_location  rating  bean_type broad_origin
# ...

# %%
cacao.bar_id.nunique()
# Out:
# 1795

# %%
cacao.bar_id.plot()

# %%
cacao.drop(['bar_id'], inplace = True, axis = 1)  # удаляем столбец с id

# %%
cacao
# Out:
#        company     specific_origin   ref  review_date cocoa_percent  \
# 0     A. Morin         Agua Grande  1876         2016           63%
# 1     A. Morin               Kpime  1676         2015           70%
# 2     A. Morin              Atsane  1676         2015          670%
# 3     A. Morin               Akata  1680         2015           70%
# 4     A. Morin              Quilla  1704         2015           70%
# ...        ...                 ...   ...          ...           ...
# 1790    Zotter                Peru   647         2011           70%
# 1791    Zotter               Congo   749         2011           65%
# 1792    Zotter        Kerala State   749         2011           65%
# 1793    Zotter        Kerala State   781         2011           62%
# 1794    Zotter  Brazil, Mitzi Blue   486         2010           65%
#
#      company_location  rating  bean_type broad_origin
# 0              France   11.50                Sao Tome
# ...

# %%
cacao.company.value_counts()  # количество компаний
# Out:
#                                      99
# Soma                                 45
# Fresco                               26
# Bonnat                               26
# Pralus                               25
#                                      ..
# Forever Cacao                         1
# Cacaosuyo (Theobroma Inversiones)     1
# Lilla                                 1
# Santome                               1
# Tan Ban Skrati                        1
# Name: company, Length: 408, dtype: int64

# %%
cacao.company = cacao.company[cacao.company.value_counts() > 10]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-24-dc8e7deaf600> in <module>
# ----> 1 cacao.company = cacao.company[cacao.company.value_counts() > 10]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     906
#     907         if com.is_bool_indexer(key):
# --> 908             key = check_bool_indexer(self.index, key)
#     909
#     910         return self._get_with(key)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2315         mask = isna(result._values)
#    2316         if mask.any():
# -> 2317             raise IndexingError(
#    2318                 "Unalignable boolean Series provided as "
#    2319                 "indexer (index of the boolean Series and of "
#
# ...
